# %%
import os
import pandas as pd

# %%
# 여러 예보 데이터들을 모아둘 list 만들기
list_ulsan = []
list_dangjin = []

# %%
# 직접 가져와서 정리한 2~6월 예보 데이터 추가
dir_data = './new_dataset_v2'

df = pd.read_csv(os.path.join(dir_data, 'new_fcst_dangjin_6.csv'))
list_dangjin.append(df)

df = pd.read_csv(os.path.join(dir_data, 'new_fcst_ulsan_6.csv'))
list_ulsan.append(df)

# %%
# api로 가져온 7월 예보
dir_api = './fcst_api_data'
list_api_data = os.listdir(dir_api)

for f in list_api_data:
    if 'dangjin' in f:
        print(f'{f} -> dangjin')
        df = pd.read_csv(os.path.join(dir_api, f), index_col=None)
        list_dangjin.append(df)
    elif 'ulsan' in f:
        print(f'{f} -> ulsan')
        df = pd.read_csv(os.path.join(dir_api, f), index_col=None)
        list_ulsan.append(df)
# Out:
# fcst_dangjin_20210702_1425.csv -> dangjin
# fcst_dangjin_20210703_1414.csv -> dangjin
# fcst_dangjin_20210704_0705.csv -> dangjin
# fcst_dangjin_20210704_1755.csv -> dangjin
# fcst_dangjin_20210705_1429.csv -> dangjin
# fcst_dangjin_20210707_0937.csv -> dangjin
# fcst_dangjin_20210707_1614.csv -> dangjin
# fcst_dangjin_20210708_1107.csv -> dangjin
# fcst_dangjin_20210708_2249.csv -> dangjin
# fcst_ulsan_20210702_1425.csv -> ulsan
# fcst_ulsan_20210703_1414.csv -> ulsan
# fcst_ulsan_20210704_0705.csv -> ulsan
# fcst_ulsan_20210704_1755.csv -> ulsan
# fcst_ulsan_20210705_1429.csv -> ulsan
# fcst_ulsan_20210707_0937.csv -> ulsan
# fcst_ulsan_20210707_1614.csv -> ulsan
# fcst_ulsan_20210708_1107.csv -> ulsan
# fcst_ulsan_20210708_2249.csv -> ulsan

# %%
df_ulsan = pd.DataFrame()
for ulsan in list_ulsan:
    df_ulsan = pd.concat([df_ulsan, ulsan])

df_dangjin = pd.DataFrame()
for dangjin in list_dangjin:
    df_dangjin = pd.concat([df_dangjin, dangjin])

# %%
df_ulsan
# Out:
#            Forecast time  forecast  Temperature  Humidity  WindSpeed  \
# 0    2020-12-01 02:00:00         4         10.0      35.0        3.0
# 1    2020-12-01 02:00:00         7          6.0      55.0        2.6
# 2    2020-12-01 02:00:00        10          4.0      45.0        3.1
# 3    2020-12-01 02:00:00        13          3.0      50.0        2.9
# 4    2020-12-01 02:00:00        16          3.0      55.0        3.1
# ..                   ...       ...          ...       ...        ...
# 543  2021-07-08 20:00:00        72         28.0      80.0        2.9
# 544  2021-07-08 20:00:00        73         27.0      85.0        2.7
# 545  2021-07-08 20:00:00        74         27.0      85.0        2.5
# 546  2021-07-08 20:00:00        75         26.0      85.0        2.4
# 547  2021-07-08 20:00:00        76         26.0      90.0        2.0
#
#      WindDirection  Cloud
# 0            356.0    1.0
# 1            335.0    1.0
# 2            328.0    3.0
# 3            326.0    3.0
# 4            329.0    3.0
# ..             ...    ...
# 543          224.0    1.0
# 544          239.0    1.0
# 545          236.0    1.0
# 546          234.0    1.0
# 547          237.0    3.0
#
# [36308 rows x 7 columns]

# %%
df_dangjin
# Out:
#            Forecast time  forecast  Temperature  Humidity  WindSpeed  \
# 0    2020-12-01 02:00:00         4          4.0      40.0        4.3
# 1    2020-12-01 02:00:00         7          3.0      50.0        3.0
# 2    2020-12-01 02:00:00        10          2.0      50.0        2.7
# 3    2020-12-01 02:00:00        13          1.0      55.0        3.2
# 4    2020-12-01 02:00:00        16          1.0      55.0        3.0
# ..                   ...       ...          ...       ...        ...
# 543  2021-07-08 20:00:00        72         25.0      85.0        2.1
# 544  2021-07-08 20:00:00        73         24.0      85.0        1.9
# 545  2021-07-08 20:00:00        74         24.0      90.0        1.6
# 546  2021-07-08 20:00:00        75         23.0      90.0        1.4
# 547  2021-07-08 20:00:00        76         23.0      90.0        1.4
#
#      WindDirection  Cloud
# 0            352.0    3.0
# 1             12.0    3.0
# 2             27.0    3.0
# 3             22.0    3.0
# 4             24.0    4.0
# ..             ...    ...
# 543          227.0    1.0
# 544          227.0    3.0
# 545          220.0    1.0
# 546          197.0    1.0
# 547          163.0    3.0
#
# [36308 rows x 7 columns]

# %%
df_ulsan.to_csv(os.path.join(dir_data, 'new_fcst_ulsan.csv'), index=None)
df_dangjin.to_csv(os.path.join(dir_data, 'new_fcst_dangjin.csv'), index=None)
